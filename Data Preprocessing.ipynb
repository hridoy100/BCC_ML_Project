# %%
import shutil
import os, sys, random
import xml.etree.ElementTree as ET
from glob import glob
import pandas as pd
from shutil import copyfile
import pandas as pd
from sklearn import preprocessing, model_selection
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import patches
import numpy as np
import os

# %%
annotations = sorted(glob('BCCD/Annotations/*.xml'))

df = []
cnt = 0
for file in annotations:
    prev_filename = file.split('/')[-1].split('.')[0] + '.jpg'
    filename = str(cnt) + '.jpg'
    row = []
    parsedXML = ET.parse(file)
    for node in parsedXML.getroot().iter('object'):
        blood_cells = node.find('name').text
        xmin = int(node.find('bndbox/xmin').text)
        xmax = int(node.find('bndbox/xmax').text)
        ymin = int(node.find('bndbox/ymin').text)
        ymax = int(node.find('bndbox/ymax').text)
        row = [prev_filename, filename, blood_cells, xmin, xmax, ymin, ymax]
        df.append(row)
    cnt += 1

data = pd.DataFrame(df, columns=['prev_filename', 'filename', 'cell_type', 'xmin', 'xmax', 'ymin', 'ymax'])
data[['prev_filename','filename', 'cell_type', 'xmin', 'xmax', 'ymin', 'ymax']].to_csv('blood_cell_detection.csv', index=False)
data
# Out:
#                          prev_filename filename  cell_type  xmin  xmax  ymin  \
# 0     Annotations\BloodImage_00000.jpg    0.jpg        WBC   260   491   177
# 1     Annotations\BloodImage_00000.jpg    0.jpg        RBC    78   184   336
# 2     Annotations\BloodImage_00000.jpg    0.jpg        RBC    63   169   237
# 3     Annotations\BloodImage_00000.jpg    0.jpg        RBC   214   320   362
# 4     Annotations\BloodImage_00000.jpg    0.jpg        RBC   414   506   352
# ...                                ...      ...        ...   ...   ...   ...
# 4883  Annotations\BloodImage_00410.jpg  363.jpg  Platelets   239   291   275
# 4884  Annotations\BloodImage_00410.jpg  363.jpg  Platelets   121   189   260
# 4885  Annotations\BloodImage_00410.jpg  363.jpg  Platelets    57   104   119
# 4886  Annotations\BloodImage_00410.jpg  363.jpg  Platelets     1    29   286
# 4887  Annotations\BloodImage_00410.jpg  363.jpg        WBC   367   611   166
#
#       ymax
# 0      376
# 1      435
# 2      336
# 3      461
# 4      445
# ...    ...
# 4883   321
# 4884   320
# 4885   167
# 4886   327
# 4887   394
#
# [4888 rows x 7 columns]

# %%
img_width = 640
img_height = 480

def width(df):
    return int(df.xmax - df.xmin)
def height(df):
    return int(df.ymax - df.ymin)
def x_center(df):
    return int(df.xmin + (df.width/2))
def y_center(df):
    return int(df.ymin + (df.height/2))
def w_norm(df):
    return df/img_width
def h_norm(df):
    return df/img_height

df = pd.read_csv('blood_cell_detection.csv')

le = preprocessing.LabelEncoder()
le.fit(df['cell_type'])
print(le.classes_)
labels = le.transform(df['cell_type'])
df['labels'] = labels

df['width'] = df.apply(width, axis=1)
df['height'] = df.apply(height, axis=1)

df['x_center'] = df.apply(x_center, axis=1)
df['y_center'] = df.apply(y_center, axis=1)

df['x_center_norm'] = df['x_center'].apply(w_norm)
df['width_norm'] = df['width'].apply(w_norm)

df['y_center_norm'] = df['y_center'].apply(h_norm)
df['height_norm'] = df['height'].apply(h_norm)

df.head(30)
# Out:
# ['Platelets' 'RBC' 'WBC']
#                        prev_filename filename cell_type  xmin  xmax  ymin  \
# 0   Annotations\BloodImage_00000.jpg    0.jpg       WBC   260   491   177
# 1   Annotations\BloodImage_00000.jpg    0.jpg       RBC    78   184   336
# 2   Annotations\BloodImage_00000.jpg    0.jpg       RBC    63   169   237
# 29   188       1     91      97       530       139       0.828125
#
#     width_norm  y_center_norm  height_norm
# 0     0.360938       0.575000     0.414583
# 1     0.165625       0.802083     0.206250
# 2     0.165625       0.595833     0.206250
# 3     0.165625       0.856250     0.206250
# 4     0.143750       0.829167     0.193750
# 5     0.132812       0.843750     0.206250
# 6     0.153125       0.929167     0.141667
# 7     0.134375       0.802083     0.216667
# 8     0.142187       0.922917     0.154167
# 9     0.143750       0.258333     0.208333
# 10    0.145313       0.256250     0.162500
# 11    0.164062       0.185417     0.208333
# 12    0.145313       0.510417     0.208333
# 13    0.145313       0.127083     0.208333
# 14    0.145313       0.468750     0.208333
# 15    0.178125       0.087500     0.170833
# 16    0.178125       0.275000     0.172917
# 17    0.179688       0.393750     0.189583
# 18    0.175000       0.375000     0.206250
# 19    0.150000       0.275000     0.181250
# 20    0.340625       0.827083     0.343750
# 21    0.156250       0.847917     0.193750
# 22    0.145313       0.497917     0.250000
# 23    0.135937       0.916667     0.166667
# 24    0.135937       0.358333     0.166667
# 25    0.135937       0.697917     0.166667
# 26    0.142187       0.693750     0.208333
# 27    0.142187       0.825000     0.227083
# 28    0.142187       0.229167     0.202083
# 29    0.142187       0.289583     0.202083

# %%
df_train, df_valid = model_selection.train_test_split(df, test_size=0.1, random_state=13, shuffle=True)
print(df_train.shape, df_valid.shape)
# Out:
# (4399, 16) (489, 16)

# %%
df_train
# Out:
#                          prev_filename filename cell_type  xmin  xmax  ymin  \
# 2516  Annotations\BloodImage_00206.jpg  176.jpg       RBC   285   379   263
# 2164  Annotations\BloodImage_00172.jpg  148.jpg       RBC   566   640   274
# 2045  Annotations\BloodImage_00164.jpg  140.jpg       RBC   309   415   233
# 688   Annotations\BloodImage_00037.jpg   35.jpg       RBC    48   147     5
# 2116  Annotations\BloodImage_00169.jpg  145.jpg       RBC   330   457   222
# ...                                ...      ...       ...   ...   ...   ...
# 153   Annotations\BloodImage_00008.jpg    8.jpg       RBC   221   327    18
# 866   Annotations\BloodImage_00046.jpg   44.jpg       RBC   138   251   294
# 2790  Annotations\BloodImage_00228.jpg  197.jpg       RBC    52   150    78
# 74    Annotations\BloodImage_00004.jpg    4.jpg       RBC   510   606   112
# 338   Annotations\BloodImage_00018.jpg   18.jpg       RBC   243   333   189
#
#       ymax  labels  width  height  x_center  y_center  x_center_norm  \
# 2516   355       1     94      92       332       309       0.518750
# 2164   386       1     74     112       603       330       0.942187
# 2045   354       1    106     121       362       293       0.565625
# 688     81       1     99      76        97        43       0.151562
# 2116   341       1    127     119       393       281       0.614062
# ...    ...     ...    ...     ...       ...       ...            ...
# 153    116       1    106      98       274        67       0.428125
# 866    398       1    113     104       194       346       0.303125
# 2790   181       1     98     103       101       129       0.157812
# 74     195       1     96      83       558       153       0.871875
# 338    277       1     90      88       288       233       0.450000
#
#       width_norm  y_center_norm  height_norm
# 2516    0.146875       0.643750     0.191667
# 2164    0.115625       0.687500     0.233333
# 2045    0.165625       0.610417     0.252083
# 688     0.154688       0.089583     0.158333
# 2116    0.198437       0.585417     0.247917
# ...          ...            ...          ...
# 153     0.165625       0.139583     0.204167
# 866     0.176563       0.720833     0.216667
# 2790    0.153125       0.268750     0.214583
# 74      0.150000       0.318750     0.172917
# 338     0.140625       0.485417     0.183333
#
# [4399 rows x 16 columns]
